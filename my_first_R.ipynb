# %% [markdown]
# <a href="https://colab.research.google.com/github/mikecroucher/r_testing/blob/master/my_first_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data=c(1,5,-3,7,0)
plot(data)
# Out:
# plot without title
